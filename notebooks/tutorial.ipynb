# %%
import sys
import os

sys.path.append(os.path.abspath("../src/visuals"))

# %%
from matplotlib import pyplot as plt

# %%
from plots import plot_zt

plot_zt("../data/Zt/N100_T10M_t0100K_alpha2.0_tauinf.csv")

# %%
from plots import plot_zt

csv_filepaths = [
    "../data/Zt/N100_T1M_t01K_alpha2.0_tau100.csv",
    "../data/Zt/N100_T1M_t01K_alpha2.0_tauinf.csv"
]

for csv_filepath in csv_filepaths:
    plot_zt(csv_filepath)
