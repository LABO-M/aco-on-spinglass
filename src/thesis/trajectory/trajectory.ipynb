# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# データの読み込み
df = pd.read_csv("trajectory_data.csv")

# プロット
plt.figure(figsize=(10, 6))

# trial_idごとにプロット
for tid in df['trial_id'].unique():
    subset = df[df['trial_id'] == tid]
    plt.plot(subset['alpha'], subset['m'], alpha=0.6, linewidth=1.5)

plt.axhline(0, color='gray', linestyle='--', linewidth=0.8)
plt.xlabel(r'Annealing Parameter $\alpha$')
plt.ylabel(r'Magnetization $m$')
plt.title('Time Evolution of Magnetization (Trajectory Analysis)')
plt.grid(True, alpha=0.3)
plt.ylim(-1.1, 1.1)

# 理論的な分岐点(概算)などを書き込むと良い
# plt.axvline(x=1/(1+2*0.1), color='red', linestyle=':', label=r'$\alpha_c$')

plt.show()
