# %%
import pandas as pd
import matplotlib.pyplot as plt

seed = 7000

data = pd.read_csv(f"/home/mori-lab/shimizu/ACO/ACO-on-SpinGlass/src/sampling/return_M/data/seed{seed}/tau1K_h0.001_J0.1_α_inc1.0e-6/N100_alpha0.9_sample1K.csv")
data = data['M']

plt.hist(data, bins = 50, density=True)
plt.yscale('log')
plt.show()

import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(f"/home/mori-lab/shimizu/ACO/ACO-on-SpinGlass/src/sampling/return_M/data/seed{seed}/tau1K_h0.001_J0.1_α_inc1.0e-6/N100_alpha0.8_sample1K.csv")
data = data['M']

plt.hist(data, bins = 50, density=True)
plt.yscale('log')
plt.show()

import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(f"/home/mori-lab/shimizu/ACO/ACO-on-SpinGlass/src/sampling/return_M/data/seed{seed}/tau1K_h0.001_J0.1_α_inc1.0e-6/N100_alpha0.83515_sample1K.csv")
data = data['M']

plt.hist(data, bins = 50, density=True)
plt.yscale('log')
plt.show()
